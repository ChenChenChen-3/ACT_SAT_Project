# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# By analyssis the data, I want to find the relationship between:
# 1. SAT and ACT score and attend rate.
# 2. Visualize to povid that increase the attend rate help to increase the score.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports packages
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# Read the SAT & ACT
act_2017 = pd.read_csv('../data/act_2017.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.shape
# Out:
# (52, 7)

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# 1) SAT and ACT are the test that prove for all the student in united states. The dataframe above shows the participation rate, score's for all sections and the total score.
# 2) ACT score has national average, but SAT score hasn't.
# 3) Some of the states take ACT score as primary, the others are more focus on SAT, so the participation rate is different.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
# Yes. The table doesn't have missing data, although it has some errors.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
act_2017.max()
# Out:
# State            Wyoming
# Participation        98%
# English             25.5
# Math                25.3
# Reading               26
# Science             24.9
# Composite           25.5
# dtype: object

# %% [markdown]
# A) The ACT Composite score of Wyoming state is 20.2x instead of 20.2.
# B)
# SAT
# Min
# Participation                              2%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
#
# Max
# Participation                            100%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
#
#
# ACT
# Min
# Participation         8%
# English             16.3
# Math                  18
# Reading             18.1
# Science              2.3
# Composite           17.8
#
# Max
# Participation       100%
# English             25.5
# Math                25.3
# Reading               26
# Science             24.9
# Composite           25.5

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
act_2017 = act_2017.replace("20.2x", "20.2")
act_2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %%
sat_2017['Math'][20]= 524.
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# A) the participation rate is object, the ACT dataframe is int
# B)
# 1) The participation rate should be covert from object to float
# 2) Covert act dataframe from int to float
# 3) Add a national avgerage for SAT

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %% [markdown]
# ### Three different way to use inside the def
# - for loop : calling the cell in column and convert to float
# - .astype(float) : function we can use to convert 'Series' in Pandas to float
# - .map() : use function to do-somthing in 'Series'
#     - ex: use lambda cell: function(cell)

# %% [markdown]
# ### Method 1: for loop
# ```def as_float(dataframe, column_name):
#         for cell in dataframe[column_name]:
#             float(cell)
#         return dataframe```
#
# ### Method 2: .astpye()
#
# ```def as_float(dataframe, column_name):
#         dataframe[column_name].astype(float)
#         return dataframe```

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
act_2017['Participation'] = act_2017['Participation'].map(lambda part : part.replace("%" , ""))

# %%
# Method 3: .map() use function to do-somthing in 'Series'   
#           + lambda: work for individaul cell, ex: cell: function(cell)
#           + float(): work for individaul cell, in this case, following the lambda
def as_float(dataframe, column_name):    
    dataframe[column_name] = dataframe[column_name].map(lambda part : float(part))
    return dataframe

# %%
# Combine everything in a line
# act_2017['Participation']= act_2017['Participation'].map(lambda part : float(part.replace("%" , ""))/100)

# %%
act_2017_new = as_float(act_2017, "Participation")

# %%
act_2017_new['Participation']= act_2017_new['Participation']/100
act_2017_new.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
sat_2017['Participation']= sat_2017['Participation'].map(lambda part : float(part.replace("%" , ""))/100)
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_2017_new = as_float(act_2017, "Composite")

# %%
sat_2017_new = as_float(sat_2017, "Evidence-Based Reading and Writing")
sat_2017_new = as_float(sat_2017, "Math")
sat_2017_new = as_float(sat_2017, "Total")

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
act_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
sat_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null float64
# Math                                  51 non-null float64
# Total                                 51 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
act_2017_new.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
sat_2017_new.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama           0.05                               593.0  572.0
# 1      Alaska           0.38                               547.0  533.0
# 2     Arizona           0.30                               563.0  553.0
# 3    Arkansas           0.03                               614.0  594.0
# 4  California           0.53                               531.0  524.0
#
#     Total
# 0  1165.0
# 1  1080.0
# 2  1116.0
# 3  1208.0
# 4  1055.0

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
act_2017_new_col = {'State':'state' ,
                     'Participation':'participation_act17',
                     'English':'english_act17',
                     'Math':'math_act17',
                     'Reading':'reading_act17',
                     'Science':'science_act17',
                     'Composite':'total_act17'} 
act_2017_new.rename(columns = act_2017_new_col, inplace = True)
act_2017_new.head()
# Out:
#       state  participation_act17  english_act17  math_act17  reading_act17  \
# 0  National                 0.60           20.3        20.7           21.4
# 1   Alabama                 1.00           18.9        18.4           19.7
# 2    Alaska                 0.65           18.7        19.8           20.4
# 3   Arizona                 0.62           18.6        19.8           20.1
# 4  Arkansas                 1.00           18.9        19.0           19.7
#
#    science_act17  total_act17
# 0           21.0         21.0
# 1           19.4         19.2
# 2           19.9         19.8
# 3           19.8         19.7
# 4           19.5         19.4

# %%
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama           0.05                               593.0  572.0
# 1      Alaska           0.38                               547.0  533.0
# 2     Arizona           0.30                               563.0  553.0
# 3    Arkansas           0.03                               614.0  594.0
# 4  California           0.53                               531.0  524.0
#
#     Total
# 0  1165.0
# 1  1080.0
# 2  1116.0
# 3  1208.0
# 4  1055.0

# %%
sat_2017_new = sat_2017
sat_2017_new_col = {'State':'state' ,
                     'Participation':'participation_sat17',
                     'Evidence-Based Reading and Writing':'reading_writing_sat17',
                     'Math':'math_sat17',
                     'Total':'total_sat17'} 
sat_2017_new.rename(columns = sat_2017_new_col, inplace = True)
sat_2017_new.head()
# Out:
#         state  participation_sat17  reading_writing_sat17  math_sat17  \
# 0     Alabama                 0.05                  593.0       572.0
# 1      Alaska                 0.38                  547.0       533.0
# 2     Arizona                 0.30                  563.0       553.0
# 3    Arkansas                 0.03                  614.0       594.0
# 4  California                 0.53                  531.0       524.0
#
#    total_sat17
# 0       1165.0
# 1       1080.0
# 2       1116.0
# 3       1208.0
# 4       1055.0

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature              |Type    |Dataset |Description|
# |---------------------|--------|------- |-----------|
# |participation_sat17  |float   |SAT 2017|The probability of participation rate of SAT Test Score for each state.|
# |reading_writing_sat17|float   |SAT 2017|Evidence-Based Reading and Writing Section Score of 2017 SAT Test for each state.|
# |math_sat17           |float   |SAT 2017|Math Section Score of 2017 SAT Test for each state.|
# |total_sat17          |float   |SAT 2017|Total Score of 2017 SAT Test for each state.|
# |xxx_sat18            |---     |SAT 2018|Infomation of SAT Test hold in 2018 for each state.|
# |participation_act17  |float   |ACT 2017|The probability of participation rate of ACT Test Score for each state.|
# |english_act17        |float   |ACT 2017|English Section Score of 2017 ACT Test for each state.|
# |math_act17           |float   |ACT 2017|Math Section Score of 2017 ACT Test for each state.|
# |reading_act17        |float   |ACT 2017|Reading Section Score of 2017 ACT Test for each state.|
# |science_act17        |float   |ACT 2017|Science Section Score of 2017 ACT Test for each state.|
# |total_act17          |float   |ACT 2017|Total Score of 2017 ACT Test for each state.|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
sat_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                    51 non-null object
# participation_sat17      51 non-null float64
# reading_writing_sat17    51 non-null float64
# math_sat17               51 non-null float64
# total_sat17              51 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
act_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# state                  52 non-null object
# participation_act17    52 non-null float64
# english_act17          52 non-null float64
# math_act17             52 non-null float64
# reading_act17          52 non-null float64
# science_act17          52 non-null float64
# total_act17            52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
act_2017_new = act_2017_new.drop([0])

# %%
act_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
# state                  51 non-null object
# participation_act17    51 non-null float64
# english_act17          51 non-null float64
# math_act17             51 non-null float64
# reading_act17          51 non-null float64
# science_act17          51 non-null float64
# total_act17            51 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#DataFrame.merge(self, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None
combined_2017 = pd.DataFrame.merge(self = sat_2017_new, right= act_2017_new, how = 'inner')
combined_2017.head()
# Out:
#         state  participation_sat17  reading_writing_sat17  math_sat17  \
# 0     Alabama                 0.05                  593.0       572.0
# 1      Alaska                 0.38                  547.0       533.0
# 2     Arizona                 0.30                  563.0       553.0
# 3    Arkansas                 0.03                  614.0       594.0
# 4  California                 0.53                  531.0       524.0
#
#    total_sat17  participation_act17  english_act17  math_act17  reading_act17  \
# 0       1165.0                 1.00           18.9        18.4           19.7
# 1       1080.0                 0.65           18.7        19.8           20.4
# 2       1116.0                 0.62           18.6        19.8           20.1
# 3       1208.0                 1.00           18.9        19.0           19.7
# 4       1055.0                 0.31           22.5        22.7           23.1
#
#    science_act17  total_act17
# 0           19.4         19.2
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#df = pd.DataFrame(dict) saving the dataframe df.to_csv('file1.csv') 
combined_2017.to_csv("combined_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv("../data/SAT2018_Testing _Data - SAT 2018.csv")
act_2018 = pd.read_csv('../data/SAT2018_Testing _Data - ACT 2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# make sure the data type
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null object
# Composite        52 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# covert the participation to float for both sat_2018 & act_2018
sat_2018['Participation'] = sat_2018['Participation'].map(lambda cell: float(cell.replace("%", ""))/100)
print(sat_2018.info())
act_2018['Participation'] = act_2018['Participation'].map(lambda cell: float(cell.replace("%",""))/100)
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
# convert sat_2018 from int to float
sat_2018_new = as_float(sat_2018, 'Evidence-Based Reading and Writing' )
sat_2018_new = as_float(sat_2018, 'Math' )
sat_2018_new = as_float(sat_2018, 'Total' )

# %%
# change the column_name for both sat and act
sat_2018_new_col = {'State':'state' ,
                     'Participation':'participation_sat18',
                     'Evidence-Based Reading and Writing':'reading_writing_sat18',
                     'Math':'math_sat18',
                     'Total':'total_sat18'} 
sat_2018_new.rename(columns = sat_2018_new_col, inplace = True)
print(sat_2018_new.head())
act_2018_new = act_2018
act_2018_new_col = {'State':'state' ,
                     'Participation':'participation_act18',
                     'Composite':'total_act18'} 
act_2018_new.rename(columns = act_2018_new_col, inplace = True)
act_2018_new.head()
# Out:
#           state  participation_sat18  reading_writing_sat18  math_sat18  \
# 0     Minnesota                 0.04                  643.0       655.0
# 1     Wisconsin                 0.03                  641.0       653.0
# 2  North Dakota                 0.02                  640.0       643.0
# 3          Iowa                 0.03                  634.0       631.0
# 4        Kansas                 0.04                  633.0       631.0
#
#    total_sat18
# 0       1298.0
# 1       1294.0
# 2       1283.0
# 3       1265.0
# 4       1265.0
#         state  participation_act18  total_act18
# 0     Alabama                 1.00         19.1
# 1      Alaska                 0.33         20.8
# 2     Arizona                 0.66         19.2
# 3    Arkansas                 1.00         19.4
# 4  California                 0.27         22.7

# %%
# merge the sat_2018 & act_2018 together
combined_2018 = pd.DataFrame.merge(sat_2018_new, right = act_2018_new, how ='inner')
combined_2018.head()
# Out:
#           state  participation_sat18  reading_writing_sat18  math_sat18  \
# 0     Minnesota                 0.04                  643.0       655.0
# 1     Wisconsin                 0.03                  641.0       653.0
# 2  North Dakota                 0.02                  640.0       643.0
# 3          Iowa                 0.03                  634.0       631.0
# 4        Kansas                 0.04                  633.0       631.0
#
#    total_sat18  participation_act18  total_act18
# 0       1298.0                 0.99         21.3
# 1       1294.0                 1.00         20.5
# 2       1283.0                 0.98         20.3
# 3       1265.0                 0.68         21.8
# 4       1265.0                 0.71         21.6

# %%
# merge the combine_2017 with combined_2018
final_all = pd.DataFrame.merge(combined_2017, right = combined_2018, how = 'inner')
final_all.head()
# Out:
#         state  participation_sat17  reading_writing_sat17  math_sat17  \
# 0     Alabama                 0.05                  593.0       572.0
# 1      Alaska                 0.38                  547.0       533.0
# 2     Arizona                 0.30                  563.0       553.0
# 3    Arkansas                 0.03                  614.0       594.0
# 4  California                 0.53                  531.0       524.0
#
#    total_sat17  participation_act17  english_act17  math_act17  reading_act17  \
# 0       1165.0                 1.00           18.9        18.4           19.7
# 1       1080.0                 0.65           18.7        19.8           20.4
# 2       1116.0                 0.62           18.6        19.8           20.1
# 3       1208.0                 1.00           18.9        19.0           19.7
# 4       1055.0                 0.31           22.5        22.7           23.1
#
# ...

# %%
# save the clean final.csv file
final_all.to_csv('final_all.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final_all.describe().T
# Out:
#                        count         mean        std     min        25%  \
# participation_sat17     48.0     0.400208   0.345460    0.02     0.0400
# reading_writing_sat17   48.0   570.395833  43.969399  503.00   535.7500
# math_sat17              48.0   558.520833  45.869839  492.00   524.0000
# total_sat17             48.0  1129.000000  89.521185  996.00  1059.0000
# participation_act17     48.0     0.645000   0.319920    0.08     0.3100
# english_act17           48.0    20.966667   2.313359   16.30    19.3000
# math_act17              48.0    21.247917   1.933247   18.00    19.7000
# reading_act17           48.0    22.060417   2.017238   18.10    20.5000
# science_act17           48.0    21.066667   3.239473    2.30    19.9750
# total_act17             48.0    21.568750   1.977765   17.80    19.9500
# participation_sat18     48.0     0.464583   0.369594    0.02     0.0475
# reading_writing_sat18   48.0   564.166667  46.916555  480.00   534.7500
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
import math 

def std_dev(sample):
    sum_s = 0
    n = len(sample)
    mean_s = sum(sample)/len(sample)
    for i in sample:
        sum_s += (i-mean_s)**2  
    return np.sqrt(sum_s/n)

# %%
mylst = [1,2]
std_dev(mylst)
# Out:
# 0.5

# %%
np.std(mylst)
# Out:
# 0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final_all.columns
# Out:
# Index(['state', 'participation_sat17', 'reading_writing_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'total_act17', 'participation_sat18',
#        'reading_writing_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'total_act18'],
#       dtype='object')

# %%
std_dev(final_all['participation_sat17'])
# Out:
# 0.3418423709799916

# %%
{i: std_dev(final_all[i]) 
 for i in final_all.columns if final_all[i].dtypes == float}
# Out:
# {'participation_sat17': 0.3418423709799916,
#  'reading_writing_sat17': 43.50897397057556,
#  'math_sat17': 45.38951309835297,
#  'total_sat17': 88.58376450192966,
#  'participation_act17': 0.31657016073323574,
#  'english_act17': 2.28913496519731,
#  'math_act17': 1.9130026118789165,
#  'reading_act17': 1.9961149331611365,
#  'science_act17': 3.2055507413790156,
#  'total_act17': 1.957055212344983,
#  'participation_sat18': 0.36572393011061705,
#  'reading_writing_sat18': 46.425268502783645,
#  'math_sat18': 46.659667443866574,
#  'total_sat18': 91.95061136586074,
#  'participation_act18': 0.3356182106700012,
#  'total_act18': 2.067187434387334}

# %%
{ column : std_dev(final_all[column]) for column in final_all.columns if final_all[column].dtypes == float}
# Out:
# {'participation_sat17': 0.3418423709799916,
#  'reading_writing_sat17': 43.50897397057556,
#  'math_sat17': 45.38951309835297,
#  'total_sat17': 88.58376450192966,
#  'participation_act17': 0.31657016073323574,
#  'english_act17': 2.28913496519731,
#  'math_act17': 1.9130026118789165,
#  'reading_act17': 1.9961149331611365,
#  'science_act17': 3.2055507413790156,
#  'total_act17': 1.957055212344983,
#  'participation_sat18': 0.36572393011061705,
#  'reading_writing_sat18': 46.425268502783645,
#  'math_sat18': 46.659667443866574,
#  'total_sat18': 91.95061136586074,
#  'participation_act18': 0.3356182106700012,
#  'total_act18': 2.067187434387334}

# %%
np.std(final_all)
# Out:
# participation_sat17       0.341842
# reading_writing_sat17    43.508974
# math_sat17               45.389513
# total_sat17              88.583765
# participation_act17       0.316570
# english_act17             2.289135
# math_act17                1.913003
# reading_act17             1.996115
# science_act17             3.205551
# total_act17               1.957055
# participation_sat18       0.365724
# reading_writing_sat18    46.425269
# math_sat18               46.659667
# total_sat18              91.950611
# participation_act18       0.335618
# total_act18               2.067187
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# It is the different between sample std.dev and population std.dev, the sample std.dev use 1/(n-1) to indicate that we are working on a sample instead of the whole population.

# %%
np.std(final_all['total_act18'], ddof=1)
# Out:
# 2.0890630428886343

# %%
final_all[['total_act18']].describe()
# Out:
#        total_act18
# count    48.000000
# mean     21.558333
# std       2.089063
# min      17.700000
# 25%      20.000000
# 50%      21.300000
# 75%      23.725000
# max      25.600000

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Q & A
# **Which states have the highest and lowest participation rates for the:**
#
# **2017 SAT?**
# - Delaware, Connecticut, and Michigan have hightest participation rate of 100%
# - Iowa, North Dakota have lowest participation rate of 2%
#
# **2018 SAT?**
# - Idaho, Connecticut, Delaware, Michigan, Colorado have hightest participation rate of 100%
# - North Dakota have lowest participation rate of 2%
#
# **2017 ACT?**
# - Colorado, Arkansas, Wyoming, Montana, Louisiana, Minnesota, Missouri, Nevada, North Carolina, South Carolina, Tennessee, Utah, Wiscoin, Kentucky,and Alabama have hightest participation rate of 100%
# - Maine	have lowest participation rate of 8%
#
# **2018 ACT?**
# - Colorado, Arkansas, Wyoming, Montana, Louisiana, Minnesota, Missouri, Nevada, North Carolina, South Carolina, Tennessee, Utah, Wiscoin, Kentucky, Alabama, Nebraska, and Ohio have hightest participation rate of 100%
# - Maine have lowest participation rate of 7%
#
# **Which states have the highest and lowest total/composite scores for the:**
#
# **2017 SAT?**
# - Minnesota	have hightest total score of 1295.0
# - Delaware	have lowest total score of 996.0
#
# **2018 SAT?**
# - Minnesota have hightest total score of 1298.0
# - Delaware have lowest total score of 998.0
#
# **2017 ACT?**
# - New Hampshire have hightest total score of 25.5
# - Nevada have lowest total score of 17.8
#
# **2018 ACT?**
# - Connecticut have hightest total score of 25.6
# - Nevada have lowest total score of 17.7
#
# **Do any states with 100% participation on a given test have a rate change year-to-year?**
# - Nebraska and Ohio have increase the participation rate of ACT test to 100% on 2018.
# - Colorado decrease 70% of participation rate in ACT and has 100% SAT participation rate in 2018.
# - Idaho increase the participation rate from 93% to 100%
#
# **Do any states show have >50% participation on both tests either year?**
# - Hawaii, Georgia, Florida, North Carolina, and South Carolina
#
# **Based on what you've just observed, have you identified any states that you're especially interested in?**
# - I am interest in why Colorado change the different type of test to take and what is the reason that make Colorado has such sigenificant change.

# %%
#srot the lowest and hightest participation rate of sat17,sat18,act17,act18
#by use .sort_value().head() and .tail()
final_all.sort_values(by='participation_act18', ascending= False).head(2)
# Out:
#        state  participation_sat17  reading_writing_sat17  math_sat17  \
# 0    Alabama                 0.05                  593.0       572.0
# 16  Kentucky                 0.04                  631.0       616.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 0        1165.0                  1.0           18.9        18.4
# 16       1247.0                  1.0           19.6        19.4
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# 0            19.7           19.4         19.2                 0.06
# 16           20.5           20.1         20.0                 0.04
#
#     reading_writing_sat18  math_sat18  total_sat18  participation_act18  \
# 0                   595.0       571.0       1166.0                  1.0
# 16                  630.0       618.0       1248.0                  1.0
#
#     total_act18
# 0          19.1
# 16         20.2

# %%
#srot the lowest and hightest total score of sat17,sat18,act17,act18
#by use .sort_value().head() and .tail()
final_all.sort_values(by='total_sat17', ascending= False).head(2)
# Out:
#         state  participation_sat17  reading_writing_sat17  math_sat17  \
# 22  Minnesota                 0.03                  644.0       651.0
# 46  Wisconsin                 0.03                  642.0       649.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 22       1295.0                  1.0           20.4        21.5
# 46       1291.0                  1.0           19.7        20.4
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# 22           21.8           21.6         21.5                 0.04
# 46           20.6           20.9         20.5                 0.03
#
#     reading_writing_sat18  math_sat18  total_sat18  participation_act18  \
# 22                  643.0       655.0       1298.0                 0.99
# 46                  641.0       653.0       1294.0                 1.00
#
#     total_act18
# 22         21.3
# 46         20.5

# %%
final_all.sort_values(by='total_sat17', ascending= False).tail(2)
# Out:
#        state  participation_sat17  reading_writing_sat17  math_sat17  \
# 21  Michigan                  1.0                  509.0       495.0
# 7   Delaware                  1.0                  503.0       492.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 21       1005.0                 0.29           24.1        23.7
# 7         996.0                 0.18           24.1        23.4
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# 21           24.5           23.8         24.1                  1.0
# 7            24.8           23.6         24.1                  1.0
#
#     reading_writing_sat18  math_sat18  total_sat18  participation_act18  \
# 21                  511.0       499.0       1011.0                 0.22
# 7                   505.0       492.0        998.0                 0.17
#
#     total_act18
# 21         24.2
# 7          23.8

# %%
#srot the lowest and hightest total score of sat17,sat18,act17,act18
#by use .sort_value(ascending = True/False).head()
final_all.sort_values(by='total_sat18', ascending= False).head(2)
# Out:
#         state  participation_sat17  reading_writing_sat17  math_sat17  \
# 22  Minnesota                 0.03                  644.0       651.0
# 46  Wisconsin                 0.03                  642.0       649.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 22       1295.0                  1.0           20.4        21.5
# 46       1291.0                  1.0           19.7        20.4
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# 22           21.8           21.6         21.5                 0.04
# 46           20.6           20.9         20.5                 0.03
#
#     reading_writing_sat18  math_sat18  total_sat18  participation_act18  \
# 22                  643.0       655.0       1298.0                 0.99
# 46                  641.0       653.0       1294.0                 1.00
#
#     total_act18
# 22         21.3
# 46         20.5

# %%
final_all.sort_values(by='total_act18', ascending= True).head(2)
# Out:
#              state  participation_sat17  reading_writing_sat17  math_sat17  \
# 26          Nevada                 0.26                  563.0       553.0
# 37  South Carolina                 0.50                  543.0       521.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 26       1116.0                  1.0           16.3        18.0
# 37       1064.0                  1.0           17.5        18.6
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# 26           18.1           18.2         17.8                 0.23
# 37           19.1           18.9         18.7                 0.55
#
#     reading_writing_sat18  math_sat18  total_sat18  participation_act18  \
# 26                  574.0       566.0       1140.0                  1.0
# 37                  547.0       523.0       1070.0                  1.0
#
#     total_act18
# 26         17.7
# 37         18.3

# %%
#filter the state that take both tests > 50% each year, change the columns to sat17 and act17 to check
final_all[(final_all['participation_sat18'] > 0.5) & (final_all['participation_act18'] > 0.5)]
# Out:
#              state  participation_sat17  reading_writing_sat17  math_sat17  \
# 8          Florida                 0.83                  520.0       497.0
# 9          Georgia                 0.61                  535.0       515.0
# 10          Hawaii                 0.55                  544.0       541.0
# 31  North Carolina                 0.49                  546.0       535.0
# 37  South Carolina                 0.50                  543.0       521.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 8        1017.0                 0.73           19.0        19.4
# 9        1050.0                 0.55           21.0        20.9
# 10       1085.0                 0.90           17.8        19.2
# 31       1081.0                 1.00           17.8        19.3
# 37       1064.0                 1.00           17.5        18.6
#
#     reading_act17  science_act17  total_act17  participation_sat18  \
# ...

# %%
final_all[(final_all['participation_sat18'] < 0.05) & (final_all['total_sat18'] > 1250)]
# Out:
#            state  participation_sat17  reading_writing_sat17  math_sat17  \
# 14          Iowa                 0.02                  641.0       635.0
# 15        Kansas                 0.04                  632.0       628.0
# 22     Minnesota                 0.03                  644.0       651.0
# 23      Missouri                 0.03                  640.0       631.0
# 25      Nebraska                 0.03                  629.0       625.0
# 32  North Dakota                 0.02                  635.0       621.0
# 46     Wisconsin                 0.03                  642.0       649.0
# 47       Wyoming                 0.03                  626.0       604.0
#
#     total_sat17  participation_act17  english_act17  math_act17  \
# 14       1275.0                 0.67           21.2        21.3
# 15       1260.0                 0.73           21.1        21.3
# 22       1295.0                 1.00           20.4        21.5
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
sns.set(font_scale=2.5)
plt.subplots(figsize=(25, 20))
sns.heatmap(final_all.corr(method = "pearson"),annot = True, annot_kws={"size": 20})

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, xlabels, ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2))                  # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols = 2,figsize= (20,20)) # You'll want to specify your figsize
    ax = ax.ravel()                                               # Ravel turns a matrix into a vector, which is easier to iterate
    sns.set(font_scale=2)
    
    for i, column in enumerate(list_of_columns):                  # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins = 10) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(xlabels[i])
        ax[i].set_ylabel(ylabels[i])
        #avoid title/label to overlap
        plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    return

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates for SAT & ACT
columns =['participation_sat17','participation_sat18','participation_act17','participation_act18']
titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']
xlabel =["Participation Rate","Participation Rate","Participation Rate","Participation Rate"]
ylabel = ["Number of States","Number of States","Number of States","Number of States"]
subplot_histograms(final_all, columns, titles, xlabel,ylabel)

# %%
# Math scores for SAT & ACT
columns =['math_sat17','math_sat18','math_act17']
titles = ['SAT 2017','SAT 2018','ACT 2017']
xlabel =["Math Score","Math Score","Math Score"]
ylabel = ["Number of States","Number of States","Number of States"]
subplot_histograms(final_all, columns, titles, xlabel,ylabel)

# %%
# Reading/verbal scores for SAT & ACT
columns =['reading_writing_sat17','reading_writing_sat18','reading_act17']
titles = ['SAT 2017','SAT 2018','ACT 2017']
xlabel =["Reading/Verbal Score","Reading/verbal Score","Reading/verbal Score"]
ylabel = ["Number of States","Number of States","Number of States"]
subplot_histograms(final_all, columns, titles, xlabel,ylabel)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
final_all.columns
# Out:
# Index(['state', 'participation_sat17', 'reading_writing_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'total_act17', 'participation_sat18',
#        'reading_writing_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'total_act18'],
#       dtype='object')

# %%
#avoid the overlaying 
plt.tight_layout(pad=10.0, w_pad=10.0, h_pad=500.0)
plt.figure(figsize=(25, 25))

# plt.subplot(231) means we have 2 rows, 3 column, and are referencing plot 1.
#SAT vs. ACT math scores for 2017
ax1 = plt.subplot(2,3,1)
ax1.set_title('Math SAT v.s. ACT 2017')
ax1.scatter(x='math_sat17', y='math_act17', data= final_all, c="r")
ax1.set(xlabel = "SAT Math",ylabel = "ACT Math")

# plt.subplot(232) means we have 2 rows, 3 column, and are referencing plot 2.
#SAT vs. ACT verbal/reading scores for 2017
ax2 = plt.subplot(232)
ax2.set_title('Reading SAT v.s. ACT 2017')
ax2.scatter(x= 'reading_writing_sat17', y='reading_act17', data =final_all, c ="g")
ax2.set(xlabel = "SAT Reading & Writing",ylabel = "ACT Reading")

# plt.subplot(233) means we have 2 rows, 3 column, and are referencing plot 3.
#SAT vs. ACT total/composite scores for 2017
ax3 = plt.subplot(233)
ax3.set_title('Total SAT v.s. ACT 2017')
ax3.scatter(x='total_sat17', y= 'total_act17', data = final_all,c ="black")
ax3.set(xlabel = "SAT Total",ylabel = "ACT Total")

# plt.subplot(234) means we have 2 rows, 3 column, and are referencing plot 4.
#Total scores for SAT 2017 vs. 2018
ax4 = plt.subplot(234)
ax4.set_title('Total SAT 2017 v.s. 2018')
ax4.scatter(x='total_sat17', y= 'total_sat18', data = final_all, c="darkviolet")
ax4.set(xlabel = "SAT 2017",ylabel = "SAT 2018")

# plt.subplot(235) means we have 2 rows, 3 column, and are referencing plot 5.
#Composite scores for ACT 2017 vs. 2018
ax5 = plt.subplot(235)
ax5.set_title('Total ACT 2017 v.s. 2018')
ax5.scatter(x='total_act17', y= 'total_act18', data = final_all)
ax5.set(xlabel = "ACT 2017",ylabel = "ACT 2018")
# Out:
# [Text(0, 0.5, 'ACT 2018'), Text(0.5, 0, 'ACT 2017')]

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
np.mean(final_all["total_sat17"])
# Out:
# 1129.0

# %%
final_all.head(2)
# Out:
#      state  participation_sat17  reading_writing_sat17  math_sat17  \
# 0  Alabama                 0.05                  593.0       572.0
# 1   Alaska                 0.38                  547.0       533.0
#
#    total_sat17  participation_act17  english_act17  math_act17  reading_act17  \
# 0       1165.0                 1.00           18.9        18.4           19.7
# 1       1080.0                 0.65           18.7        19.8           20.4
#
#    science_act17  total_act17  participation_sat18  reading_writing_sat18  \
# 0           19.4         19.2                 0.06                  595.0
# 1           19.9         19.8                 0.43                  562.0
#
#    math_sat18  total_sat18  participation_act18  total_act18
# 0       571.0       1166.0                 1.00         19.1
# 1       544.0       1106.0                 0.33         20.8

# %%
# subplot the boxplot to see the 
sns.set(font_scale=2.5)
plt.figure(figsize=(15,15))
plt.tight_layout(pad=10.0, w_pad=10.0, h_pad=10.0)

plt.subplot(2,2,1)
sns.boxplot(y=final_all["participation_sat17"], saturation=0.75, width=0.8, dodge=True, fliersize=5).set(
    xlabel="Participation Rate of SAT 2017",
    ylabel = ""
)


plt.subplot(2,2,2)
sns.boxplot(y=final_all["participation_sat18"], color = "r",saturation=0.75, width=0.8, dodge=True, fliersize=5).set(
    xlabel="Participation Rate of SAT 2018", 
    ylabel = ""
)

plt.subplot(2,2,3)
sns.boxplot(y=final_all["participation_act18"], color = "g",saturation=0.75, width=0.8, dodge=True, fliersize=5 ).set(
    xlabel="Participation Rate of ACT 2017", 
    ylabel = ""
)

plt.subplot(2,2,4)
sns.boxplot(y=final_all["participation_act18"], color = "y",saturation=0.75, width=0.8, dodge=True, fliersize=5 ).set(
    xlabel="Participation Rate of ACT 2018", 
    ylabel = ""
)
# Out:
# [Text(0, 0.5, ''), Text(0.5, 0, 'Participation Rate of ACT 2018')]

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# pair the total score of sat 2017,2018 and act 2017,2018 to see correction 
sns.pairplot(final_all, vars=["total_act17", "total_act18","total_sat17","total_sat18"], kind="reg")
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
final_all.iloc[5]
# Out:
# state                    Colorado
# participation_sat17          0.11
# reading_writing_sat17         606
# math_sat17                    595
# total_sat17                  1201
# participation_act17             1
# english_act17                20.1
# math_act17                   20.3
# reading_act17                21.2
# science_act17                20.9
# total_act17                  20.8
# participation_sat18             1
# reading_writing_sat18         519
# math_sat18                    506
# total_sat18                  1025
# participation_act18           0.3
# total_act18                  23.9
# Name: 5, dtype: object

# %%
psat18= final_all.iloc[5][11]
pact18= final_all.iloc[5][15]
Colorado_participation_2018=[psat18, pact18]
plt.pie(Colorado_participation_2018, labels = ["Colorado SAT 2018 \nparticipation rate: "+ str(psat18*100)+"%","Colorado ACT 2018\nparticipation rate:"+ str(pact18*100)+"%"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a295603c8>,
# ...
#  [Text(-0.8233618545088072, 0.7294348884854754, 'Colorado SAT 2018 \nparticipation rate: 100.0%'),
#   Text(0.8233619228034269, -0.7294348113967716, 'Colorado ACT 2018\nparticipation rate:30.0%')])

# %%
#from Matt Andrecovich - NYC- Nash
#plot 2017 to 2018 SAT participation
#set figure size
plt.figure(figsize=(20,10)) 
#plot bar graphs, "alpha" increases transparency to see both
plt.bar(final_all['state'], final_all['participation_sat18'],color = "darkorange", alpha = 0.7)
plt.bar(final_all['state'], final_all['participation_sat17'], color = "royalblue", alpha = 0.5)
#rotate x axis
plt.xticks(rotation=90)
#change y label
plt.ylabel('Participation Rate')
#show both plots
plt.show()

# %%
#from Matt Andrecovich - NYC- Nash
#plot 2017 to 2018 ACT participation
#set figure size
plt.figure(figsize=(20,10)) 
#plot bar graphs, "alpha" increases transparency to see both
plt.bar(final_all['state'], final_all['participation_act18'],color = "green", alpha = 0.7)
plt.bar(final_all['state'], final_all['participation_act17'], color = "sienna", alpha = 0.5)
#rotate x axis
plt.xticks(rotation=90)
#change y label
plt.ylabel('Participation Rate')
#show both plots
plt.show()

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
# - The distribution of SAT score looks not reasonable, needs more data.
# - Significant growth in Colorado and Illinoi.
# - The ACT and SAT score in both year have bimodal distribution.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
# No, the database is too small, we need more data from the past and future to analysis.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
# - Heatmap shows that student have high math score tend to have high reading and total score.
# - From the participation histograms, we can see that the SAT participation rate is slightly increase and ACT participation rate is decrease.
# - The ACT and SAT score in both year have bimodal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
# No. Based on the definitation of the statistical inference, the sample should has large population but the data we have don't have large enough population.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
# Yes. It is appropriate to compare any kind of data if you want to find the relationship between. We can use hypothesis tests to check the is the above question appropriate.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
import scipy.stats as stats
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
control = final_all['math_sat17']
experimental = final_all['math_act17']
# Print the average of the control and experimental groups.
print("Mean of Control:" + str(np.mean(control)) )
print(f'Mean of Experimental Group: {np.mean(experimental)}')
# Print the difference of the sample means, too.
print(f'Experimental - Control Mean: {np.mean(experimental)- np.mean(control)}')

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# The reason of Colorado, Illinoi, and Rhode Island has signifatecant increase of SAT participation rate
#
# (1) Money Issue
#     Like most of the problems in the world, money is a big issue to stop student taking SAT. After 10 states(include Colorado, Illinoi, and Rhode Island) sign the contract to cover the cost of the SAT for all their public school students during 2017-2018, the participation rates boom up.
#
# (2) Transportation Issue
#     SAT change the policy and allow student to take the test in their own school instead of the other school.
#
# (3) Pre-test project
#     Many student think the pretest project is a help to improve their SAT score. The high SAT possible score will encourage students to take SAT instead of ACT.
#
# - Zhang, D. (2019). Average SAT & ACT Scores by State (Participation Adjusted). Blog.prepscholar.com. Retrieved 8 March 2019, from https://blog.prepscholar.com/average-sat-and-act-scores-by-stated-adjusted-for-participation-rate
# -(Six Reasons Not To Get Excited About The New SAT Scores. (2019). Forbes.com. Retrieved 8 March 2019, from https://www.forbes.com/sites/petergreene/2018/10/25/six-reasons-not-to-get-excited-about-the-new-sat-scores/#7f5064395b0d)
# - (Genota, L. (2019). SAT Scores Rise as Number of Test-Takers Tops 2 Million. Education Week. Retrieved 8 March 2019, from https://www.edweek.org/ew/articles/2018/10/31/sat-scores-rise-as-number-of-test-takers.html)
# - Important Dates. (2016). SAT Suite of Assessments. Retrieved 11 March 2019, from https://collegereadiness.collegeboard.org/sat-subject-tests/important-dates

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# **Conclusions**
# - SAT test has increase in the past year, the policy change since 2016 is working. It will be helpful to release benefit, working with high school for pretest project and test in student's own school.
#
# **Recommendations**
# - The SAT should sign contract with more states. The purpose are increase the participartion rate and redcuse the unnomral high score for those states that have participation rate lower than 5%.
# - SAT test hold in the Saturday, but some of the student may need to do the part-time or others. It might be helpful to change the test day in school day.
# - Push college to accept both SAT and ACT and cooperate with high school country wild. Most student choose to take the test based on what college required, what the teacher recommand and what his/her classmate taking.

# %% [markdown]
# **Thank you for the help from local instructor Boom and Laura and the GA Global Lectures instructor.
# Thanks for my classmate Noah, Masiur, Jon, Vonn, Jasmine, Phillip,and Mitchell.**
#
# ### Online Resources:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#    - https://stackoverflow.com/questions/32400867/pandas-read-csv-from-url
#    - https://www.w3schools.com/python/python_lambda.asp
#    - https://www.geeksforgeeks.org/difference-between-map-applymap-and-apply-methods-in-pandas/
#    - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
#    - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
#    - https://www.geeksforgeeks.org/saving-a-pandas-dataframe-as-a-csv/
#    - https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes
#    - https://www.mathsisfun.com/data/standard-deviation-formulas.html
#    - https://stackoverflow.com/questions/34706845/change-xticklabels-fontsize-of-seaborn-heatmap
#    - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html
#    - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter
#    - https://seaborn.pydata.org/generated/seaborn.pairplot.html
#    - https://en.wikipedia.org/wiki/List_of_regions_of_the_United_States
#    - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html
